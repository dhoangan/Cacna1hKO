# %%
import calim
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from matplotlib.backends.backend_pdf import PdfPages
from datetime import datetime
import scipy

color_palette = sns.color_palette("colorblind")
sns.set_theme(palette=color_palette, font="Arial", font_scale=1.0, style="white")

#load custom functions
import sys
import os
from pathlib import Path
module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path+"\\custom_functs")

from modules import customfunctions as cf

# %%
list_files = ["doppel_perf_ctrl_cal_FebMar2023_230307.hdf",
              "doppel_perf_old_data_only_ctrl_230307.hdf",
              "controls_from_ttap2_before210604_230313.hdf",
             "Cal_Isra_0p05uM_295_no_ctrl_230313.hdf"]
data_hdf = cf.concat_hdf_files(list_files)
# Out:
# Concatenate 4 files:
# doppel_perf_ctrl_cal_FebMar2023_230307.hdf
# doppel_perf_old_data_only_ctrl_230307.hdf
# controls_from_ttap2_before210604_230313.hdf
# Cal_Isra_0p05uM_295_no_ctrl_230313.hdf
# Done.

# %%
# data
# The DataFrame "conditions" will contain all information about conditions
print("start")
time_start = datetime.now()
now = datetime.now().strftime("%d-%b-%Y %H:%M")
print("###### date and time ######")
print(now)

#cutoff for burst parameters
co_WT = 3.737 
co_KO = 1.759

n_rec = len(data_hdf.recordings)

data = pd.DataFrame()
print(f"Processing {n_rec} recordings")

# go through all recordingd
for recording, i in zip(data_hdf.recordings, range(0,len(data_hdf.recordings))):
    print(f"{recording} --- {i+1} of {len(data_hdf.recordings)}")
    
    r = data_hdf.recordings[recording]
    

    
    # go through all cells
    for cell in r.cells:    
        # get recording information
        info = {desc: r.information[desc] for desc in r.information}
        
        c = r.cells[cell]


        if c.use:
            
            # got through all conditions
            for con in r.conditions:
                
                # get con infromation
                info["recording"] = recording
                info["start"] = int(con.start) 
                info["cell"] = cell
                info["dt"] = r.dt # Add "dt" aka seconds/frame                
                info["end"] = int(con.end)

                info.update({desc: con.information[desc] for desc in con.information}) # Add all further condition variables           

                start = int(con.start)
                end = int(con.end)
                
                #set cutoff for burst partameters depending on genotype
                if info["genotype"] == "wt":
                    cutoff = co_WT
                elif info["genotype"] == "KO":
                    cutoff = co_KO
                else:
                    print("wrong genotype!!?")
                    cutoff = np.nan
   
                
                ## pos 1 ### take the LAST 2 min of condition for pos 1 (steady-state)
                if ((con.information["pos"]  == "1")):
                    corr = int(120/r.dt) #amount of frames to be deducted from end, 2 min
                    start = int(con.end) - corr
                    info["start_corr"] = start
                    info["end_corr"] = end
                
                ## pos  2 ### take the 8th min to 10th min of condition for pos 2 (steady-state)
                if  (con.information["pos"]  == "2"):
                    add_corr = int(330/r.dt) #amount of frames to be added to start, 5.5 min
                    start = int(con.start) + add_corr
                    info["start_corr"] = start                    
                    end = info["start_corr"] + int(120/r.dt) #2 min pro condition
                    info["end_corr"] = end
                    
                ## pos  3 ### skip pos > 3
                if  (con.information["pos"]  > "2"):
                    continue
                
                
                ## get activity and burst
                activity, num_events = cf.getActivity(start, end, c, r.dt)
                list_bursts, list_ISI = cf.getBursts(list(c.get_event(list(range(start, end)))),\
                                                     dt=r.dt,  maxEventLength=cutoff)
                
                #print(list_bursts)
                
                
                info["activity"] = activity
                info["num_events"] = num_events
                info["len_seg"] = (end-start)*r.dt
                        
                if len(list_ISI) == 0:
                    info["ISI"] = np.nan
                else:
                    info["ISI"] = list_ISI["frame"].diff().iloc[1::2].mean()*r.dt
                    
                info["intraburst_freq"], info["burst_num_spikes"], info["burst_length"], \
                info["burst_n"], info["burst_per_cell_per_sec"] = cf.getBurstParams(list_bursts, r.dt, cutoff, start, end) 
                
                if ((con.information["pos"]  == "1")):
                    info["activity_pos1"] = activity    
                    info["freq_pos1"] = info["intraburst_freq"]

                if ((con.information["pos"]  == "2")):                        
                    info["activity_pos2"] = activity
                    info["freq_pos2"] = info["intraburst_freq"]
                
               
                if "control" not in info:
                    if "ctrl" not in info:
                        info["control"] = "n"
                    elif "ctrl" in info:
                        info["control"] = info["ctrl"]
                            
                if info["control"] == "y":
                    info["genotype_2"] = info["genotype"]+"_ctrl"
                else:
                    info["genotype_2"] = info["genotype"]

                data = pd.concat((data, pd.DataFrame.from_dict(info, orient="index").T), ignore_index=True)
                     
print(data.angiotensin.unique())                                                  
data["angiotensin"]=data["angiotensin"].replace("('500',)",'500')
print(data.angiotensin.unique())   

print("Done.")
print(datetime.now()-time_start)
now = datetime.now().strftime("%d-%b-%Y %H:%M")
print("###### date and time ######")
print(now)

save_filename = "data_isra_activity_burstparam.csv"

data.to_csv(save_filename)
print(f"save to {save_filename}")
# Out:
# start
# ###### date and time ######
# 04-May-2023 19:00
# Processing 52 recordings
# 230223_slice05_500pM_AngII_ctrl_results.ome.csv --- 1 of 52
# 230224_slice02_500pM_AngII_ctrl_results.csv --- 2 of 52
# 230224_slice03_500pM_AngII_ctrl_results.csv --- 3 of 52
# 230227_slice01_500pM_AngII_ctrl_results.csv --- 4 of 52
# 230228_slice01_500pM_AngII_ctrl_results.csv --- 5 of 52
# 230302_slice03_500pM_AngII_ctrl_results.csv --- 6 of 52
# 230302_slice06_500pM_AngII_ctrl_results.csv --- 7 of 52
# 220601_slice03_rec01_ctrl_dp_results.csv --- 8 of 52
# 220603_slice03_rec01_ctrl_dp_results.csv --- 9 of 52
# 220607_slice03_rec01_ctrl_dp_results.csv --- 10 of 52
# 220610_slice03_rec01_ctrl_dp_results.csv --- 11 of 52
# 201104_s4r2_Results.csv --- 12 of 52
# 201105_s4r2_Results.csv --- 13 of 52
# 210323_s4r1_Results.csv --- 14 of 52
# 210324_s4r1_Results.csv --- 15 of 52
# 210408_s6r1_Results.csv --- 16 of 52
# 210413_s2r1_Results.csv --- 17 of 52
# 210413_s5r1_Results.csv --- 18 of 52
# 210414_s4r1_Results.csv --- 19 of 52
# 210415_s4r1_Results.csv --- 20 of 52
# 210421_s3r1_Results.csv --- 21 of 52
# 210421_s5r1_Results.csv --- 22 of 52
# 210604_slice03_rec01_Results.csv --- 23 of 52
# 210622_slice04_rec01_1_Results.csv --- 24 of 52
# 211117_slice04_rec01_Results.csv --- 25 of 52
# 211214_slice04_rec01_ctrl_Results.csv --- 26 of 52
# 220128_slice05_rec01_ctrl_Results.csv --- 27 of 52
# 220204_slice01_rec01_ctrl_Results.csv --- 28 of 52
# 220211_slice03_rec01_ctrl_Results.csv --- 29 of 52
# 220211_slice05_rec01_ctrl_Results.csv --- 30 of 52
# 220217_slice01_rec01_ctrl_Results.csv --- 31 of 52
# 220405_slice04_rec01_ctrl_results.csv --- 32 of 52
# 220406_slice01_rec01_ctrl_results.csv --- 33 of 52
# 220407_slice01_rec01_ctrl_untitled_results.csv --- 34 of 52
# 220408_slice01_rec01_ctrl_Results.csv --- 35 of 52
# 210914_slice01_rec01_isra_Results.csv --- 36 of 52
# 210917_slice02_rec01_isra_Results.csv --- 37 of 52
# 211011_slice01_rec01_isra_Results.csv --- 38 of 52
# 211117_slice03_rec01_isra_Results.csv --- 39 of 52
# 211213_slice01_rec01_isra_Results.csv --- 40 of 52
# 220128_slice04_rec01_isra_Results.csv --- 41 of 52
# 220204_slice04_rec01_isra_Results.csv --- 42 of 52
# 220217_slice04_rec01_isra_Results.csv --- 43 of 52
# 220405_slice03_rec01_isra_results.csv --- 44 of 52
# 220406_slice02_rec01_isra_results.csv --- 45 of 52
# 220407_slice03_rec01_isra_results.csv --- 46 of 52
# 220407_slice04_rec01_isra_results.csv --- 47 of 52
# 220408_slice02_rec01_isra_results.csv --- 48 of 52
# 220603_slice04_rec01_isra_results.csv --- 49 of 52
# 220607_slice04_rec01_isra_results.csv --- 50 of 52
# 220610_slice04_rec01_isra_results.csv --- 51 of 52
# 220610_slice05_rec01_isra_results.csv --- 52 of 52
# ['500']
# ['500']
# Done.
# 0:06:42.358288
# ###### date and time ######
# 04-May-2023 19:07
# save to data_isra_activity_burstparam.csv

# %%
data=pd.read_csv("data_isra_activity_burstparam.csv", index_col=0)  
print("Load data")

#only keep data from pos 1 and pos 2
data=data[data["activity_pos1"]>=0.17] # drop, <1.7 spikes per 10 seconds (100 frames)
# keep recording with at least 6 cells 
drop_rec = data[data["pos"]==1]\
            .groupby(["genotype_2", "recording"])\
            .count().reset_index().query("cell<6").recording.unique()
data = data[~data.recording.isin(drop_rec)]

# annotate number of cells whithhin a recording and pos that have intraburst_freq 
data["freq_exist"] = data["intraburst_freq"]-data["intraburst_freq"]+1
n_freq = data[["recording", "pos","freq_exist"]].value_counts(dropna=False).reset_index(name='count')\
                    .query("freq_exist==1")[["recording", "pos", "count"]]
data = pd.merge(data, n_freq, on=["recording", "pos"])

#create table for analysis per recording
data_per_slice = data.groupby(["recording", "pos", "animal", "genotype_2", "control", "genotype"]).mean().reset_index()

now = datetime.now().strftime("%d-%b-%Y %H:%M")
print("###### date and time ######")
print(now)
# Out:
# Load data
# ###### date and time ######
# 04-May-2023 19:07
# <ipython-input-6-e0c237bf3005>:19: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_per_slice = data.groupby(["recording", "pos", "animal", "genotype_2", "control", "genotype"]).mean().reset_index()

# %%
print(len(data))
print(data[data["pos"]==1].activity.mean())
print(data["angiotensin"].unique())
print(data["potassium"].unique())
print(data["TTA-P2"].unique())
print(data["isra"].unique())
print(data["genotype"].unique())
print(data["control"].unique())
print(data["pos"].unique())
print(data["genotype_2"].unique())
# Out:
# 1312
# 0.7944486788617886
# [500]
# [4.]
# [ 0. nan]
# [0.    nan 0.05]
# ['wt' 'KO']
# ['y' 'n']
# [1 2]
# ['wt_ctrl' 'KO_ctrl' 'wt' 'KO']

# %%
data.groupby(["genotype_2"])["animal", "recording"].nunique()
# Out:
# <ipython-input-8-7e0405d09887>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(["genotype_2"])["animal", "recording"].nunique()
#             animal  recording
# genotype_2
# KO               6          7
# KO_ctrl          7          7
# wt               9         10
# wt_ctrl         15         17

# %%
data[data["pos"]==1].groupby(["genotype_2"])["cell"].count()
# Out:
# genotype_2
# KO         107
# KO_ctrl     83
# wt         178
# wt_ctrl    288
# Name: cell, dtype: int64

# %%
### calculate relative activity
y = "activity"
rel_y = "rel_activity"

#calculate mean over cells per genotype per pos
mean_cell_wt_ctrl_p1 = data[(data["genotype"]=="wt") &
                              (data["control"]=="y") &
                              (data["pos"]==1)][y].mean()
mean_cell_wt_ctrl_p2 = data[(data["genotype"]=="wt") &
                              (data["control"]=="y") &
                              (data["pos"]==2)][y].mean()

mean_cell_KO_ctrl_p1 = data[(data["genotype"]=="KO") &
                              (data["control"]=="y") &
                              (data["pos"]==1)][y].mean()
mean_cell_KO_ctrl_p2 = data[(data["genotype"]=="KO") &
                              (data["control"]=="y") &
                              (data["pos"]==2)][y].mean()

#calculate mean over slices per genotype per pos
mean_slice_wt_ctrl_p1 = data_per_slice[(data_per_slice["genotype_2"]=="wt_ctrl") &
                              (data_per_slice["pos"]==1)][y].mean()
mean_slice_wt_ctrl_p2 = data_per_slice[(data_per_slice["genotype_2"]=="wt_ctrl") &
                              (data_per_slice["pos"]==2)][y].mean()


mean_slice_KO_ctrl_p1 = data_per_slice[(data_per_slice["genotype_2"]=="KO_ctrl") &
                              (data_per_slice["pos"]==1)][y].mean()
mean_slice_KO_ctrl_p2 = data_per_slice[(data_per_slice["genotype_2"]=="KO_ctrl") &
                              (data_per_slice["pos"]==2)][y].mean()

# calculate rel. activity per cell 
data[rel_y] = data[y] # create column for relative activity

data[rel_y] = np.where((data['genotype'] == 'wt') & (data['pos'] == 1),
                                data[rel_y]/mean_cell_wt_ctrl_p1, data[rel_y]) 
data[rel_y] = np.where((data['genotype'] == 'wt') & (data['pos'] == 2),
                                data[rel_y]/mean_cell_wt_ctrl_p2, data[rel_y])                                            
data[rel_y] = np.where((data['genotype'] == 'KO') & (data['pos'] == 1),
                                data[rel_y]/mean_cell_KO_ctrl_p1, data[rel_y]) 
data[rel_y] = np.where((data['genotype'] == 'KO') & (data['pos'] == 2),
                                data[rel_y]/mean_cell_KO_ctrl_p2, data[rel_y]) 

# calculate rel. activity per slice 
data_per_slice[rel_y] = data_per_slice[y] # create column for relative activity

data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'wt') & (data_per_slice['pos'] == 1),
                                data_per_slice[rel_y]/mean_slice_wt_ctrl_p1, data_per_slice[rel_y]) 
data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'wt') & (data_per_slice['pos'] == 2),
                                data_per_slice[rel_y]/mean_slice_wt_ctrl_p2, data_per_slice[rel_y])                                            
data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'KO') & (data_per_slice['pos'] == 1),
                                data_per_slice[rel_y]/mean_slice_KO_ctrl_p1, data_per_slice[rel_y]) 
data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'KO') & (data_per_slice['pos'] == 2),
                                data_per_slice[rel_y]/mean_slice_KO_ctrl_p2, data_per_slice[rel_y])

# %%
### calculate relative intraburst freq
y = "intraburst_freq"
rel_y = "rel_intraburst_freq"

#calculate mean over cells per genotype per pos
mean_cell_wt_ctrl_p1 = data[(data["genotype"]=="wt") &
                              (data["control"]=="y") &
                              (data["pos"]==1)][y].mean()
mean_cell_wt_ctrl_p2 = data[(data["genotype"]=="wt") &
                              (data["control"]=="y") &
                              (data["pos"]==2)][y].mean()

mean_cell_KO_ctrl_p1 = data[(data["genotype"]=="KO") &
                              (data["control"]=="y") &
                              (data["pos"]==1)][y].mean()
mean_cell_KO_ctrl_p2 = data[(data["genotype"]=="KO") &
                              (data["control"]=="y") &
                              (data["pos"]==2)][y].mean()

#calculate mean over slices per genotype per pos
mean_slice_wt_ctrl_p1 = data_per_slice[(data_per_slice["genotype_2"]=="wt_ctrl") &
                              (data_per_slice["pos"]==1)][y].mean()
mean_slice_wt_ctrl_p2 = data_per_slice[(data_per_slice["genotype_2"]=="wt_ctrl") &
                              (data_per_slice["pos"]==2)][y].mean()


mean_slice_KO_ctrl_p1 = data_per_slice[(data_per_slice["genotype_2"]=="KO_ctrl") &
                              (data_per_slice["pos"]==1)][y].mean()
mean_slice_KO_ctrl_p2 = data_per_slice[(data_per_slice["genotype_2"]=="KO_ctrl") &
                              (data_per_slice["pos"]==2)][y].mean()

# calculate rel. activity per cell 
data[rel_y] = data[y] # create column for relative intra brust freq

data[rel_y] = np.where((data['genotype'] == 'wt') & (data['pos'] == 1),
                                data[rel_y]/mean_cell_wt_ctrl_p1, data[rel_y]) 
data[rel_y] = np.where((data['genotype'] == 'wt') & (data['pos'] == 2),
                                data[rel_y]/mean_cell_wt_ctrl_p2, data[rel_y])                                            
data[rel_y] = np.where((data['genotype'] == 'KO') & (data['pos'] == 1),
                                data[rel_y]/mean_cell_KO_ctrl_p1, data[rel_y]) 
data[rel_y] = np.where((data['genotype'] == 'KO') & (data['pos'] == 2),
                                data[rel_y]/mean_cell_KO_ctrl_p2, data[rel_y]) 

# calculate rel. activity per slice 
data_per_slice[rel_y] = data_per_slice[y] # create column for relative intra brust freq

data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'wt') & (data_per_slice['pos'] == 1),
                                data_per_slice[rel_y]/mean_slice_wt_ctrl_p1, data_per_slice[rel_y]) 
data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'wt') & (data_per_slice['pos'] == 2),
                                data_per_slice[rel_y]/mean_slice_wt_ctrl_p2, data_per_slice[rel_y])                                            
data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'KO') & (data_per_slice['pos'] == 1),
                                data_per_slice[rel_y]/mean_slice_KO_ctrl_p1, data_per_slice[rel_y]) 
data_per_slice[rel_y] = np.where((data_per_slice['genotype'] == 'KO') & (data_per_slice['pos'] == 2),
                                data_per_slice[rel_y]/mean_slice_KO_ctrl_p2, data_per_slice[rel_y])

# %%
#calculate active cells per slice
data_active_cells = pd.DataFrame()
for i in data.recording.unique():
    print(i)
    
    # number of cells per rec
    n_cells_pos1 = len(data[(data["recording"]==i) & (data["pos"]==1)])
    n_cells_pos2 = len(data[(data["recording"]==i) & (data["pos"]==2)])
    # number of cells per rec with activity higher than 0.17 1/s 
    n_active_cells = len(data[(data["recording"]==i) & (data["pos"]==2) & (data["activity"] > 0.17)])
    
    animal= data[(data["recording"]==i)]["animal"].unique()
    genotype = data[(data["recording"]==i)]["genotype"].unique()
    genotype_2 = data[(data["recording"]==i)]["genotype_2"].unique()
    control = data[(data["recording"]==i)]["control"].unique()
    
    if len(animal) | len(genotype) | len(genotype_2) | len(control) != 1:
        print("error")
    
    
    
    info = {
        "n_cells_pos1": n_cells_pos1,
        "n_cells_pos2": n_cells_pos2,
        "n_active_cells_pos2": n_active_cells,
        "n_percentage_active_cells": n_active_cells/n_cells_pos1*100,
        "recording": i,
        "animal": animal[0],
        "genotype": genotype[0],
        "genotype_2": genotype_2[0],
        "control": control[0]
        
    }
    
    data_active_cells = pd.concat((data_active_cells, pd.DataFrame.from_dict(info, orient="index").T), ignore_index=True)
data_active_cells['n_percentage_active_cells'] = pd.to_numeric(data_active_cells['n_percentage_active_cells'])
data_active_cells
# Out:
# 230223_slice05_500pM_AngII_ctrl_results.ome.csv
# 230224_slice02_500pM_AngII_ctrl_results.csv
# 230224_slice03_500pM_AngII_ctrl_results.csv
# 230227_slice01_500pM_AngII_ctrl_results.csv
# 230228_slice01_500pM_AngII_ctrl_results.csv
# 230302_slice03_500pM_AngII_ctrl_results.csv
# 230302_slice06_500pM_AngII_ctrl_results.csv
# 220601_slice03_rec01_ctrl_dp_results.csv
# 220603_slice03_rec01_ctrl_dp_results.csv
# 220607_slice03_rec01_ctrl_dp_results.csv
# 220610_slice03_rec01_ctrl_dp_results.csv
# 210323_s4r1_Results.csv
# 210324_s4r1_Results.csv
# 210421_s3r1_Results.csv
# 210421_s5r1_Results.csv
# 210622_slice04_rec01_1_Results.csv
# 211214_slice04_rec01_ctrl_Results.csv
# 220128_slice05_rec01_ctrl_Results.csv
# 220211_slice05_rec01_ctrl_Results.csv
# 220217_slice01_rec01_ctrl_Results.csv
# 220405_slice04_rec01_ctrl_results.csv
# 220406_slice01_rec01_ctrl_results.csv
# 220407_slice01_rec01_ctrl_untitled_results.csv
# 220408_slice01_rec01_ctrl_Results.csv
# 210914_slice01_rec01_isra_Results.csv
# 210917_slice02_rec01_isra_Results.csv
# 211011_slice01_rec01_isra_Results.csv
# 211117_slice03_rec01_isra_Results.csv
# 211213_slice01_rec01_isra_Results.csv
# 220128_slice04_rec01_isra_Results.csv
# 220204_slice04_rec01_isra_Results.csv
# 220217_slice04_rec01_isra_Results.csv
# 220405_slice03_rec01_isra_results.csv
# 220406_slice02_rec01_isra_results.csv
# 220407_slice03_rec01_isra_results.csv
# 220407_slice04_rec01_isra_results.csv
# 220408_slice02_rec01_isra_results.csv
# 220603_slice04_rec01_isra_results.csv
# 220607_slice04_rec01_isra_results.csv
# 220610_slice04_rec01_isra_results.csv
# 220610_slice05_rec01_isra_results.csv
#    n_cells_pos1 n_cells_pos2 n_active_cells_pos2  n_percentage_active_cells  \
# 0            21           21                  11                  52.380952
# 1            20           20                  14                  70.000000
# 2            25           25                  16                  64.000000
# 3            39           39                  30                  76.923077
# 4            19           19                   8                  42.105263
# 5            14           14                   8                  57.142857
# 6            22           22                  19                  86.363636
# 7            11           11                   9                  81.818182
# 8            26           26                  23                  88.461538
# 9            20           20                  14                  70.000000
# 10           10           10                   8                  80.000000
# 11            9            9                   7                  77.777778
# 12            8            8                   7                  87.500000
# 13           11           11                   8                  72.727273
# 14            9            9                   9                 100.000000
# 15            6            6                   6                 100.000000
# 16           12           12                   7                  58.333333
# 17            8            8                   8                 100.000000
# 18            7            7                   5                  71.428571
# 19           20           20                  15                  75.000000
# 20            8            8                   7                  87.500000
# 21           14           14                  14                 100.000000
# 22           18           18                  15                  83.333333
# 23           14           14                  12                  85.714286
# 24           25           25                  16                  64.000000
# 25           14           14                  12                  85.714286
# 26           27           27                  19                  70.370370
# 27            9            9                   3                  33.333333
# 28           31           31                  19                  61.290323
# 29           25           25                  15                  60.000000
# 30            6            6                   1                  16.666667
# 31           11           11                   7                  63.636364
# 32           14           14                   4                  28.571429
# 33           16           16                   5                  31.250000
# 34           15           15                   4                  26.666667
# 35           17           17                   4                  23.529412
# 36           14           14                   5                  35.714286
# 37           22           22                  21                  95.454545
# 38           11           11                   7                  63.636364
# 39           12           12                   7                  58.333333
# 40           16           16                   9                  56.250000
#
#                                           recording  animal genotype  \
# 0   230223_slice05_500pM_AngII_ctrl_results.ome.csv  114001       wt
# 1       230224_slice02_500pM_AngII_ctrl_results.csv  114002       wt
# 2       230224_slice03_500pM_AngII_ctrl_results.csv  114002       wt
# 3       230227_slice01_500pM_AngII_ctrl_results.csv    6092       wt
# 4       230228_slice01_500pM_AngII_ctrl_results.csv    6223       wt
# 5       230302_slice03_500pM_AngII_ctrl_results.csv    6096       KO
# 6       230302_slice06_500pM_AngII_ctrl_results.csv    6093       wt
# 7          220601_slice03_rec01_ctrl_dp_results.csv    5250       wt
# 8          220603_slice03_rec01_ctrl_dp_results.csv    5251       wt
# 9          220607_slice03_rec01_ctrl_dp_results.csv    5255       wt
# 10         220610_slice03_rec01_ctrl_dp_results.csv    5254       wt
# 11                          210323_s4r1_Results.csv    3904       wt
# 12                          210324_s4r1_Results.csv    3905       wt
# 13                          210421_s3r1_Results.csv    4050       wt
# 14                          210421_s5r1_Results.csv    4050       wt
# 15               210622_slice04_rec01_1_Results.csv    4080       wt
# 16            211214_slice04_rec01_ctrl_Results.csv    4719       wt
# 17            220128_slice05_rec01_ctrl_Results.csv    4653       KO
# 18            220211_slice05_rec01_ctrl_Results.csv    4689       KO
# 19            220217_slice01_rec01_ctrl_Results.csv    4812       wt
# 20            220405_slice04_rec01_ctrl_results.csv    4686       KO
# 21            220406_slice01_rec01_ctrl_results.csv    4690       KO
# 22   220407_slice01_rec01_ctrl_untitled_results.csv    4774       KO
# 23            220408_slice01_rec01_ctrl_Results.csv    4773       KO
# 24            210914_slice01_rec01_isra_Results.csv    4363       wt
# 25            210917_slice02_rec01_isra_Results.csv    4368       wt
# 26            211011_slice01_rec01_isra_Results.csv    4408       wt
# 27            211117_slice03_rec01_isra_Results.csv    4538       wt
# 28            211213_slice01_rec01_isra_Results.csv    4718       wt
# 29            220128_slice04_rec01_isra_Results.csv    4653       KO
# 30            220204_slice04_rec01_isra_Results.csv    4693       KO
# 31            220217_slice04_rec01_isra_Results.csv    4812       wt
# 32            220405_slice03_rec01_isra_results.csv    4686       KO
# 33            220406_slice02_rec01_isra_results.csv    4690       KO
# 34            220407_slice03_rec01_isra_results.csv    4774       KO
# 35            220407_slice04_rec01_isra_results.csv    4774       KO
# 36            220408_slice02_rec01_isra_results.csv    4773       KO
# 37            220603_slice04_rec01_isra_results.csv    5251       wt
# 38            220607_slice04_rec01_isra_results.csv    5255       wt
# 39            220610_slice04_rec01_isra_results.csv    5254       wt
# 40            220610_slice05_rec01_isra_results.csv    5254       wt
#
#    genotype_2 control
# 0     wt_ctrl       y
# 1     wt_ctrl       y
# 2     wt_ctrl       y
# 3     wt_ctrl       y
# 4     wt_ctrl       y
# 5     KO_ctrl       y
# 6     wt_ctrl       y
# 7     wt_ctrl       y
# 8     wt_ctrl       y
# 9     wt_ctrl       y
# 10    wt_ctrl       y
# 11    wt_ctrl       y
# 12    wt_ctrl       y
# 13    wt_ctrl       y
# 14    wt_ctrl       y
# 15    wt_ctrl       y
# 16    wt_ctrl       y
# 17    KO_ctrl       y
# 18    KO_ctrl       y
# 19    wt_ctrl       y
# 20    KO_ctrl       y
# 21    KO_ctrl       y
# 22    KO_ctrl       y
# 23    KO_ctrl       y
# 24         wt       n
# 25         wt       n
# 26         wt       n
# 27         wt       n
# 28         wt       n
# 29         KO       n
# 30         KO       n
# 31         wt       n
# 32         KO       n
# 33         KO       n
# 34         KO       n
# 35         KO       n
# 36         KO       n
# 37         wt       n
# 38         wt       n
# 39         wt       n
# 40         wt       n

# %%
#calculate relative numer of active cells
y = "n_percentage_active_cells"

wt_ctrl_mean = data_active_cells[data_active_cells["genotype_2"]=="wt_ctrl"].n_percentage_active_cells.mean()

KO_ctrl_mean = data_active_cells[data_active_cells["genotype_2"]=="KO_ctrl"].n_percentage_active_cells.mean()


data_active_cells["rel_percentage_active_cells"] = data_active_cells["n_percentage_active_cells"] # create column  

data_active_cells["rel_percentage_active_cells"] = np.where((data_active_cells['genotype'] == 'wt'),
                                            data_active_cells["rel_percentage_active_cells"]/wt_ctrl_mean,
                                    data_active_cells["rel_percentage_active_cells"])
data_active_cells["rel_percentage_active_cells"] = np.where((data_active_cells['genotype'] == 'KO'),
                                data_active_cells["rel_percentage_active_cells"]/KO_ctrl_mean, 
                                        data_active_cells["rel_percentage_active_cells"])

# %% [markdown]
# # Save dataframe for plotting figures

# %%
data.to_csv("isra_rel_activity_freq.csv")
data_per_slice.to_csv("isra_rel_activity_freq_per_slice.csv")
data_active_cells.to_csv("isra_active_cells_per_slice.csv")
